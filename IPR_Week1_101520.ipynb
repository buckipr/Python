# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("https://raw.githubusercontent.com/buckipr/Python/master/IPR_sample.csv")

# %%
data.head()
# Out:
#    OBJECTID  StopId                   StopName       Lat       Lon
# 0         1    5217   PICKFORDE DR & BETHEL RD  40065959 -83086596
# 1         2    6845             2425 BETHEL RD  40064526 -83084106
# 2         3    5225  BETHEL RD & WOOD RUN BLVD  40064408 -83080785
# 3         4    5609    BETHEL RD & HEDGEROW RD  40064300 -83077475
# 4         5    5218     BETHEL RD & DIERKER RD  40064184 -83074360

# %%
data.shape
# Out:
# (30, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OBJECTID  30 non-null     int64
#  1   StopId    30 non-null     int64
#  2   StopName  30 non-null     object
#  3   Lat       30 non-null     int64
#  4   Lon       30 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ KB

# %%
data.describe()
# Out:
#         OBJECTID       StopId           Lat           Lon
# count  30.000000    30.000000  3.000000e+01  3.000000e+01
# mean   15.500000  4927.500000  4.004413e+07 -8.304987e+07
# std     8.803408  1465.778874  1.816771e+04  1.910732e+04
# min     1.000000  3454.000000  4.001150e+07 -8.308660e+07
# 25%     8.250000  3482.500000  4.002903e+07 -8.306056e+07
# 50%    15.500000  5217.500000  4.004488e+07 -8.305002e+07
# 75%    22.750000  6273.750000  4.006354e+07 -8.303283e+07
# max    30.000000  7547.000000  4.006596e+07 -8.302232e+07

# %%
data['Lat']
# Out:
# 0     40065959
# 1     40064526
# 2     40064408
# 3     40064300
# 4     40064184
# 5     40064068
# 6     40063890
# 7     40063794
# 8     40062780
# 9     40061304
# 10    40060213
# 11    40056670
# 12    40054042
# 13    40050478
# 14    40046527
# 15    40043228
# 16    40040292
# 17    40036631
# 18    40030900
# 19    40028730
# 20    40029015
# 21    40029301
# 22    40032262
# 23    40029064
# 24    40027108
# 25    40024316
# 26    40020425
# 27    40018712
# 28    40015379
# 29    40011504
# Name: Lat, dtype: int64

# %%
data.Lat = data.Lat.astype(str)
data.Lon = data.Lon.astype(str)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OBJECTID  30 non-null     int64
#  1   StopId    30 non-null     int64
#  2   StopName  30 non-null     object
#  3   Lat       30 non-null     object
#  4   Lon       30 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.3+ KB

# %%
data['Lat_front'] = data['Lat'].str[:2]

# %%
data['Lat_back'] = data['Lat'].str[2:]

# %%
data['Lon_front'] = data['Lon'].str[:3]

# %%
data['Lon_back'] = data['Lon'].str[3:]

# %%
data.head()
# Out:
#    OBJECTID  StopId                   StopName       Lat        Lon Lat_front  \
# 0         1    5217   PICKFORDE DR & BETHEL RD  40065959  -83086596        40
# 1         2    6845             2425 BETHEL RD  40064526  -83084106        40
# 2         3    5225  BETHEL RD & WOOD RUN BLVD  40064408  -83080785        40
# 3         4    5609    BETHEL RD & HEDGEROW RD  40064300  -83077475        40
# 4         5    5218     BETHEL RD & DIERKER RD  40064184  -83074360        40
#
#   Lat_back Lon_front Lon_back
# 0   065959       -83   086596
# 1   064526       -83   084106
# 2   064408       -83   080785
# 3   064300       -83   077475
# 4   064184       -83   074360

# %%
column_list = ['Lon', 'Lon_front', 'Lon_back']

# %%
len(column_list)
# Out:
# 3

# %%
column_list.sort()

# %%
column_list
# Out:
# ['Lon', 'Lon_back', 'Lon_front']

# %%
data[['Lat', 'Lat_front', 'Lat_back']]
# Out:
#          Lat Lat_front Lat_back
# 0   40065959        40   065959
# 1   40064526        40   064526
# 2   40064408        40   064408
# 3   40064300        40   064300
# 4   40064184        40   064184
# 5   40064068        40   064068
# 6   40063890        40   063890
# 7   40063794        40   063794
# 8   40062780        40   062780
# 9   40061304        40   061304
# 10  40060213        40   060213
# 11  40056670        40   056670
# 12  40054042        40   054042
# 13  40050478        40   050478
# 14  40046527        40   046527
# 15  40043228        40   043228
# 16  40040292        40   040292
# 17  40036631        40   036631
# 18  40030900        40   030900
# 19  40028730        40   028730
# 20  40029015        40   029015
# 21  40029301        40   029301
# 22  40032262        40   032262
# 23  40029064        40   029064
# 24  40027108        40   027108
# 25  40024316        40   024316
# 26  40020425        40   020425
# 27  40018712        40   018712
# ...

# %%
data['Lat_front'] + "." + data['Lat_back']
# Out:
# 0     40.065959
# 1     40.064526
# 2     40.064408
# 3     40.064300
# 4     40.064184
# 5     40.064068
# 6     40.063890
# 7     40.063794
# 8     40.062780
# 9     40.061304
# 10    40.060213
# 11    40.056670
# 12    40.054042
# 13    40.050478
# 14    40.046527
# 15    40.043228
# 16    40.040292
# 17    40.036631
# 18    40.030900
# 19    40.028730
# 20    40.029015
# 21    40.029301
# 22    40.032262
# 23    40.029064
# 24    40.027108
# 25    40.024316
# 26    40.020425
# 27    40.018712
# 28    40.015379
# 29    40.011504
# dtype: object

# %%
data['y'] = data['Lat_front'] + "." + data['Lat_back']

# %%
data['x'] = data['Lon_front'] + "." + data['Lon_back']

# %%
data.head()
# Out:
#    OBJECTID  StopId                   StopName       Lat        Lon Lat_front  \
# 0         1    5217   PICKFORDE DR & BETHEL RD  40065959  -83086596        40
# 1         2    6845             2425 BETHEL RD  40064526  -83084106        40
# 2         3    5225  BETHEL RD & WOOD RUN BLVD  40064408  -83080785        40
# 3         4    5609    BETHEL RD & HEDGEROW RD  40064300  -83077475        40
# 4         5    5218     BETHEL RD & DIERKER RD  40064184  -83074360        40
#
#   Lat_back Lon_front Lon_back          y           x
# 0   065959       -83   086596  40.065959  -83.086596
# 1   064526       -83   084106  40.064526  -83.084106
# 2   064408       -83   080785  40.064408  -83.080785
# 3   064300       -83   077475  40.064300  -83.077475
# 4   064184       -83   074360  40.064184  -83.074360

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OBJECTID   30 non-null     int64
#  1   StopId     30 non-null     int64
#  2   StopName   30 non-null     object
#  3   Lat        30 non-null     object
#  4   Lon        30 non-null     object
#  5   Lat_front  30 non-null     object
#  6   Lat_back   30 non-null     object
#  7   Lon_front  30 non-null     object
#  8   Lon_back   30 non-null     object
#  9   y          30 non-null     object
#  10  x          30 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 2.7+ KB

# %%
data['x'] = data['x'].astype(float)
data['y'] = data['y'].astype(float)

# %%
sns.distplot(data['x'])

# %%
sns.distplot(data['y'])

# %%
data.head()
# Out:
#    OBJECTID  StopId                   StopName       Lat        Lon Lat_front  \
# 0         1    5217   PICKFORDE DR & BETHEL RD  40065959  -83086596        40
# 1         2    6845             2425 BETHEL RD  40064526  -83084106        40
# 2         3    5225  BETHEL RD & WOOD RUN BLVD  40064408  -83080785        40
# 3         4    5609    BETHEL RD & HEDGEROW RD  40064300  -83077475        40
# 4         5    5218     BETHEL RD & DIERKER RD  40064184  -83074360        40
#
#   Lat_back Lon_front Lon_back          y          x
# 0   065959       -83   086596  40.065959 -83.086596
# 1   064526       -83   084106  40.064526 -83.084106
# 2   064408       -83   080785  40.064408 -83.080785
# 3   064300       -83   077475  40.064300 -83.077475
# 4   064184       -83   074360  40.064184 -83.074360

# %%
data['StopName']
# Out:
# 0                PICKFORDE DR & BETHEL RD
# 1                          2425 BETHEL RD
# 2               BETHEL RD & WOOD RUN BLVD
# 3                 BETHEL RD & HEDGEROW RD
# 4                  BETHEL RD & DIERKER RD
# 5                   BETHEL RD & OLGATE LN
# 6                     BETHEL RD & REED RD
# 7                 BETHEL RD & PORTLAND ST
# 8                   GODOWN RD & BETHEL RD
# 9                 GODOWN RD & LANGLAND DR
# 10                 GODOWN RD & CHEVIOT DR
# 11                KENNY RD & WEYBRIDGE RD
# 12              KENNY RD & MERRIMAR CIR N
# 13               KENNY RD & FOLKESTONE RD
# 14                  KENNY RD & WINDHAM RD
# 15                KENNY RD & PARKLEIGH RD
# 16                    KENNY RD & MCCOY RD
# 17                KENNY RD & MILLCREEK LN
# 18                KENNY RD & RUE DE FLEUR
# 19       W NORTH BROADWAY & CLEARVIEW AVE
# 20        W NORTH BROADWAY & SHATTUCK AVE
# 21      W NORTH BROADWAY & RIVERSIDE HOSP
# ...

# %%
data[data['StopName'].str.contains("BETHEL RD")]
# Out:
#    OBJECTID  StopId                   StopName       Lat        Lon Lat_front  \
# 0         1    5217   PICKFORDE DR & BETHEL RD  40065959  -83086596        40
# 1         2    6845             2425 BETHEL RD  40064526  -83084106        40
# 2         3    5225  BETHEL RD & WOOD RUN BLVD  40064408  -83080785        40
# 3         4    5609    BETHEL RD & HEDGEROW RD  40064300  -83077475        40
# 4         5    5218     BETHEL RD & DIERKER RD  40064184  -83074360        40
# 5         6    5608      BETHEL RD & OLGATE LN  40064068  -83070427        40
# 6         7    5771        BETHEL RD & REED RD  40063890  -83066030        40
# 7         8    5772    BETHEL RD & PORTLAND ST  40063794  -83061802        40
# 8         9    6532      GODOWN RD & BETHEL RD  40062780  -83056846        40
#
#   Lat_back Lon_front Lon_back          y          x
# 0   065959       -83   086596  40.065959 -83.086596
# 1   064526       -83   084106  40.064526 -83.084106
# ...

# %%
data.loc[data['StopName'].str.contains("BETHEL RD"), "Bethel"] = 1

# %%
data
# Out:
#     OBJECTID  StopId                             StopName       Lat  \
# 0          1    5217             PICKFORDE DR & BETHEL RD  40065959
# 1          2    6845                       2425 BETHEL RD  40064526
# 2          3    5225            BETHEL RD & WOOD RUN BLVD  40064408
# 3          4    5609              BETHEL RD & HEDGEROW RD  40064300
# 4          5    5218               BETHEL RD & DIERKER RD  40064184
# 5          6    5608                BETHEL RD & OLGATE LN  40064068
# 6          7    5771                  BETHEL RD & REED RD  40063890
# 7          8    5772              BETHEL RD & PORTLAND ST  40063794
# 8          9    6532                GODOWN RD & BETHEL RD  40062780
# 9         10    3454              GODOWN RD & LANGLAND DR  40061304
# 10        11    3455               GODOWN RD & CHEVIOT DR  40060213
# 11        12    3472              KENNY RD & WEYBRIDGE RD  40056670
# 12        13    3474            KENNY RD & MERRIMAR CIR N  40054042
# ...

# %%
data.loc[~data['StopName'].str.contains("BETHEL RD"), "Bethel"] = 0

# %%
data
# Out:
#     OBJECTID  StopId                             StopName       Lat  \
# 0          1    5217             PICKFORDE DR & BETHEL RD  40065959
# 1          2    6845                       2425 BETHEL RD  40064526
# 2          3    5225            BETHEL RD & WOOD RUN BLVD  40064408
# 3          4    5609              BETHEL RD & HEDGEROW RD  40064300
# 4          5    5218               BETHEL RD & DIERKER RD  40064184
# 5          6    5608                BETHEL RD & OLGATE LN  40064068
# 6          7    5771                  BETHEL RD & REED RD  40063890
# 7          8    5772              BETHEL RD & PORTLAND ST  40063794
# 8          9    6532                GODOWN RD & BETHEL RD  40062780
# 9         10    3454              GODOWN RD & LANGLAND DR  40061304
# 10        11    3455               GODOWN RD & CHEVIOT DR  40060213
# 11        12    3472              KENNY RD & WEYBRIDGE RD  40056670
# 12        13    3474            KENNY RD & MERRIMAR CIR N  40054042
# ...

# %%
data['Bethel'].value_counts()
# Out:
# 0.0    21
# 1.0     9
# Name: Bethel, dtype: int64

# %%
data['Over4000'].value_counts()
# Out:
# 1.0    16
# 0.0    14
# Name: Over4000, dtype: int64

# %%
data.loc[data['StopId']>4000, "Over4000"] = 1

# %%
data.loc[data['StopId']<4000, "Over4000"] = 0

# %%
data
# Out:
#     OBJECTID  StopId                             StopName       Lat  \
# 0          1    5217             PICKFORDE DR & BETHEL RD  40065959
# 1          2    6845                       2425 BETHEL RD  40064526
# 2          3    5225            BETHEL RD & WOOD RUN BLVD  40064408
# 3          4    5609              BETHEL RD & HEDGEROW RD  40064300
# 4          5    5218               BETHEL RD & DIERKER RD  40064184
# 5          6    5608                BETHEL RD & OLGATE LN  40064068
# 6          7    5771                  BETHEL RD & REED RD  40063890
# 7          8    5772              BETHEL RD & PORTLAND ST  40063794
# 8          9    6532                GODOWN RD & BETHEL RD  40062780
# 9         10    3454              GODOWN RD & LANGLAND DR  40061304
# 10        11    3455               GODOWN RD & CHEVIOT DR  40060213
# 11        12    3472              KENNY RD & WEYBRIDGE RD  40056670
# 12        13    3474            KENNY RD & MERRIMAR CIR N  40054042
# ...

# %%
data.to_csv("IPR_cleaned.csv", index=False)

# %%
import folium

# %%
m = folium.Map(location=[40, -83], zoom_start = 12)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data.loc[5]['x']
# Out:
# -83.070427

# %%
data.loc[0]['y']
# Out:
# 40.065959

# %% [raw]
# for i in range(0, len(data)):
#     print(i)

# %%
for i in range(0, len(data)):
    folium.Circle(location = [data.loc[i]['y'], data.loc[i]['x']],
                 popup=data.iloc[i]['StopId'],
                  radius = 5, color = 'red').add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
